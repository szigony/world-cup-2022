# %%
import os
import numpy as np
import pandas as pd
import networkx as nx

# %%
a = pd.read_csv('country_player_history/Brazil.csv')
a[a.name.str.contains('Neymar')].drop(columns = ['current_league', 'current_team', 'shirt_number', 'market_value'])
# Out:
#        name current_market_value country    from_date      to_date  \
# 152  Neymar             €75.00m   Brazil  Aug 3, 2017          NaN
# 153  Neymar             €75.00m   Brazil  Jul 1, 2013  Aug 3, 2017
# 154  Neymar             €75.00m   Brazil  Jan 1, 2009  Jul 1, 2013
# 155  Neymar             €75.00m   Brazil          NaN  Jan 1, 2009
#
#           old_team   new_team  transfer_fee
# 152       Paris SG        NaN           NaN
# 153      Barcelona   Paris SG   222000000.0
# 154      Santos FC  Barcelona    88000000.0
# 155  Santos FC U20  Santos FC           NaN

# %%
sum([len(pd.read_csv('country_player_history/' + fn)) for fn in os.listdir('country_player_history')])
# Out:
# 6648

# %% [markdown]
# ### 1. Parse the country colors

# %% [markdown]
# #### 1.1. Color the player network

# %%
countries = [c.split('.csv')[0] for c in os.listdir('country_player_history')]
len(countries)
# Out:
# 32

# %%
df_cntr = pd.read_excel('country_colors.xlsx')[['country', 'hex']]
len(set(df_cntr.country).intersection(set(countries)))
# Out:
# 29

# %%
set(countries).difference(set(df_cntr.country))
# Out:
# {'England', 'United States', 'Wales'}

# %%
colors_d = df_cntr[df_cntr.country.isin(countries)].set_index('country').to_dict()['hex']
colors_d.update({'United States' : '#3C3B6E', 'Wales' : '#CF1E26', 'England' : '#FFFFFF'})
colors_d
# Out:
# {'Argentina': '#74ACDF',
#  'Australia': '#00008B',
#  'Belgium': '#FAE042',
#  'Brazil': '#009B3A',
#  'Cameroon': '#FCD116',
#  'Canada': '#FF0000',
#  'Costa Rica': '#002B7F',
#  'Croatia': '#FF0000',
#  'Denmark': '#C60C30',
#  'Ecuador': '#FFDD00',
#  'France': '#002395',
#  'Germany': '#000000',
#  'Ghana': '#006B3F',
#  'Iran': '#FFFFFF',
#  'Japan': '#BC002D',
#  'Mexico': '#006847',
#  'Morocco': '#C1272D',
#  'Netherlands': '#21468B',
#  'Poland': '#DC143C',
#  'Portugal': '#006600',
#  'Qatar': '#8D1B3D',
#  'Saudi Arabia': '#006C35',
#  'Senegal': '#00853F',
#  'Serbia': '#C6363C',
#  'South Korea': '#030303',
#  'Spain': '#FFC400',
#  'Switzerland': '#FF0000',
#  'Tunisia': '#E70013',
#  'Uruguay': '#9E830E',
#  'United States': '#3C3B6E',
#  'Wales': '#CF1E26',
#  'England': '#FFFFFF'}

# %% [markdown]
# ### 2. Color teams based on countries

# %%
G = nx.read_gexf('player_teammate_network.gexf')
G.number_of_nodes(), G.number_of_edges()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-01e71d81e4d9> in <module>
# ----> 1 G = nx.read_gexf('player_teammate_network.gexf')
#       2 G.number_of_nodes(), G.number_of_edges()
#
# <decorator-gen-813> in read_gexf(path, node_type, relabel, version)
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _open_file(func_to_be_decorated, *args, **kwargs)
#     211         if isinstance(path, str):
#     212             ext = splitext(path)[1]
# --> 213             fobj = _dispatch_dict[ext](path, mode=mode)
#     214             close_fobj = True
#     215         elif hasattr(path, "read"):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'player_teammate_network.gexf'

# %%
names_colors = {}
for fn in os.listdir('countries_players'):
    country = fn.split('_pla')[0]
    color   = colors_d[country]
    df      = pd.read_csv('countries_players/' + fn, index_col = 0)
    names   = df.name.to_list()
    names_colors.update({n : color for n in names})

len(names_colors)
# Out:
# 830

# %%
df_colors = pd.DataFrame(list(G.nodes()))
df_colors['color'] = df_colors[0].map(names_colors)
df_colors.set_index(0, inplace = True)
df_colors.index.name='Id'
df_colors.to_csv('node_colors_people_country.csv')
df_colors
# Out:
#                     color
# Id
# Aaron Long        #3C3B6E
# Cristian Roldán   #3C3B6E
# DeAndre Yedlin    #3C3B6E
# Tyler Adams       #3C3B6E
# Aaron Mooy        #00008B
# ...                   ...
# Yu-min Cho        #030303
# Munir             #C1272D
# Samuel Oum Gouet  #FCD116
# Pathé Ciss        #00853F
# Payam Niazmand    #FFFFFF
#
# [818 rows x 1 columns]

# %%
limit = 59999999
df_nodes = pd.read_csv('node_values.csv')
labels  = df_nodes.Id.to_list()
print(sum([x > limit for i, x in enumerate(df_nodes.current_market_value.to_list())]))
df_nodes['newlabel'] = [labels[i] if x > limit else '' for i, x in enumerate(df_nodes.current_market_value.to_list())]
df_nodes.set_index('Id', inplace = True)
df_nodes[['newlabel']].to_csv('node_labels_people_country.csv')
# Out:
# 51

# %% [markdown]
# #### 1.2. Color the team network

# %%
clubs_countries = pd.read_csv('team_league_v2.csv').set_index('current_team').to_dict()['current_league_country']

G_club = nx.read_gexf('club_migration_network.gexf')
print(G_club.number_of_nodes(), G_club.number_of_edges())

df_club = pd.DataFrame(G_club.nodes(), columns = ['Id'])
# Out:
# 643 1207

# %%
s2 = set(clubs_countries)

# %%
s1 = set(df_club.Id)

# %%
len(s1), len(s2), len(s1.intersection(s2)), len(s2.difference(s1))
# Out:
# (643, 293, 239, 54)

# %%
df_club
# Out:
#                    Id
# 0             Man Utd
# 1                Ajax
# 2       Werder Bremen
# 3             Everton
# 4       PSV Eindhoven
# 5               Inter
# 6          Heerenveen
# 7           Sparta R.
# 8           Barcelona
# 9           Willem II
# 10           Ajax U21
# 11             Celtic
# 12      B. Leverkusen
# 13       Man City U23
# 14         Sevilla FC
# 15    Bor. M'gladbach
# 16          Twente FC
# 17      De Graafschap
# 18      Middlesbrough
# 19        Atalanta BC
# 20           Juventus
# 21      Bayern Munich
# 22     Olympique Lyon
# 23        Bournemouth
# 24           Man City
# 25            Chelsea
# 26      Feyenoord U17
# 27        Chelsea U18
# 28        Club Brugge
# 29            Vitesse
# 30          Feyenoord
# 31              Lazio
# 32            Watford
# 33         AZ Alkmaar
# 34              Spurs
# 35         Ajax Youth
# 36    PSV Eindhoven Y
# 37          Monterrey
# 38      Royal Antwerp
# 39        Almere City
# 40        Southampton
# 41          Liverpool
# 42       FC Groningen
# 43      VfL Wolfsburg
# 44            Burnley
# 45    Heracles Almelo
# 46      Slavia Prague
# 47            Benfica
# 48        SönderjyskE
# 49            HB Köge
# 50        Trabzonspor
# 51      FC Copenhagen
# 52              Parma
# 53            Cardiff
# 54            Bologna
# 55      Nordsjaelland
# 56      Odense BK U19
# 57           Ajax U19
# 58         Fiorentina
# 59          Brentford
# 60         Bröndby IF
# 61       Hamburger SV
# 62      Lyngby BK U19
# 63    Hamburger SV II
# 64    Atlético Madrid
# 65           Valencia
# 66      Celta de Vigo
# 67              Évian
# 68       E. Frankfurt
# 69       Union Berlin
# 70         AC Horsens
# 71     Austria Vienna
# 72     Udinese Calcio
# 73     Crystal Palace
# 74          Sampdoria
# 75    Midtjylland U19
# 76      FC Twente U19
# 77           KRC Genk
# 78         Aalborg BK
# 79           OGC Nice
# 80      Silkeborg U19
# 81          Leicester
# 82              Leeds
# 83         CD Leganés
# 84           Toulouse
# 85         Esbjerg fB
# 86          Odense BK
# 87         Hertha BSC
# 88        RB Salzburg
# 89     FC Midtjylland
# 90     TSG Hoffenheim
# 91       Silkeborg IF
# 92           AC Milan
# 93         Fenerbahce
# 94         LOSC Lille
# 95         US Palermo
# 96      Bor. Dortmund
# 97        Galatasaray
# 98          Lyngby BK
# 99         RB Leipzig
# 100            Toluca
# 101            Chivas
# 102        Real Betis
# 103             Atlas
# 104    Dep. La Coruña
# 105      CD Cruz Azul
# 106           América
# 107     Santos Laguna
# 108    Standard Liège
# 109         Mérida FC
# 110      Club Tijuana
# 111        SSC Napoli
# 112           Pachuca
# 113          FC Porto
# 114           AS Roma
# 115     Real Sociedad
# 116          Espanyol
# 117        UNAM Pumas
# 118             Genoa
# 119        Cimarrones
# 120      Querétaro FC
# 121            Wolves
# 122            Necaxa
# 123       River Plate
# 124            Ascoli
# 125    1.FC Nuremberg
# 126      Huddersfield
# 127      Al-Rayyan SC
# 128       Al-Nassr FC
# 129          Aalesund
# 130            GZ R&F
# 131           OC Safi
# 132          Wydad AC
# 133    Stade Brestois
# 134          Paris SG
# 135       Real Madrid
# 136     RSC Charleroi
# 137         Lommel SK
# 138           El Ahly
# 139          Qatar SC
# 140   Raja Casablanca
# 141            Girona
# 142     Atl. Madrid B
# 143       Hércules CF
# 144       Barcelona B
# 145   Real Valladolid
# 146      O. Khouribga
# 147            Rennes
# 148          West Ham
# 149             Dijon
# 150         FUS Rabat
# 151       AM Football
# 152        Angers SCO
# 153          Mouscron
# 154     Hellas Verona
# 155        FC Utrecht
# 156              Bari
# 157       Sangiustese
# 158    Dibba Fujairah
# 159         Málaga CF
# 160        Málaga U19
# 161           PSV U21
# 162   Kawasaki Front.
# 163     F. Düsseldorf
# 164   Kashima Antlers
# 165     Cercle Brugge
# 166        Sagan Tosu
# 167    Yokohama F. M.
# 168         Lierse SK
# 169       Santa Clara
# 170       Sporting CP
# 171      Júbilo Iwata
# 172     VfB Stuttgart
# 173         Marseille
# 174        Urawa Reds
# 175    Kashiwa Reysol
# 176       Hannover 96
# 177       Stade Reims
# 178          Brighton
# 179         VVV-Venlo
# 180       SC Freiburg
# 181       Gamba Osaka
# 182      Portimonense
# 183   Shimizu S-Pulse
# 184           Arsenal
# 185      Sint-Truiden
# 186    Avispa Fukuoka
# 187          Partizan
# 188   Sanf. Hiroshima
# 189            Monaco
# 190      Cerezo Osaka
# 191            Cesena
# 192          FC Tokyo
# 193           Peñarol
# 194      Athletico-PR
# 195        UD Almería
# 196        Villarreal
# 197          Nacional
# 198      Defensor U19
# 199          CA Cerro
# 200        Danubio FC
# 201           Orlando
# 202       RM Castilla
# 203         Wanderers
# 204          Cruzeiro
# 205          Flamengo
# 206          Defensor
# 207     Dynamo Moscow
# 208       Man Utd U21
# 209           Pescara
# 210     Wanderers U19
# 211       Pescara U19
# 212         Famalicão
# 213          CA Fénix
# 214            Getafe
# 215         Palmeiras
# 216      Liverpool FC
# 217      Boca Juniors
# 218      Boston River
# 219         Rentistas
# 220        Sunderland
# 221   Vélez Sarsfield
# 222        HNK Rijeka
# 223     Dinamo Zagreb
# 224      RCD Mallorca
# 225        CA Osasuna
# 226           Crotone
# 227      FC St. Pauli
# 228     NK Lokomotiva
# 229        HNK Gorica
# 230    Inter Zapresic
# 231         NK Osijek
# 232           Rangers
# 233           Trapani
# 234           Catania
# 235        Zenit S-Pb
# 236       Dynamo Kyiv
# 237         NK Zagreb
# 238        FC Sochaux
# 239        Hajduk U17
# 240      FC Sochaux B
# 241    HNK Rijeka Jgd
# 242       Inter Youth
# 243    Legia Warszawa
# 244      Hajduk Split
# 245         RNK Split
# 246   Hrv Dragovoljac
# 247     UD Las Palmas
# 248        AEK Athens
# 249       Rubin Kazan
# 250     Spezia Calcio
# 251          Sassuolo
# 252     Ulsan Hyundai
# 253          CC Yatai
# 254   Jeonnam Dragons
# 255     Kustosija U17
# 256   I. Zapresic U17
# 257       CSKA Moscow
# 258             Wigan
# 259            Fulham
# 260       Everton U23
# 261      Philadelphia
# 262         Newcastle
# 263           Seattle
# 264             Molde
# 265       Antalyaspor
# 266     New York City
# 267           Norwich
# 268          Colorado
# 269              LAFC
# 270       New England
# 271       CD Tenerife
# 272         Nashville
# 273            Bolton
# 274       New York RB
# 275     FC Schalke 04
# 276        Stoke City
# 277         Sheff Utd
# 278           Swansea
# 279      Nottm Forest
# 280           Reading
# 281           Wrexham
# 282     Dundee United
# 283       Exeter City
# 284       Barnsley FC
# 285           Ipswich
# 286      Forest Green
# 287        Al-Sadd SC
# 288          El-Jaish
# 289          Lekhwiya
# 290        VfL Bochum
# 291    VfL Bochum U19
# 292     Chelsea Youth
# 293     FC Bayern U17
# 294     Stuttgart U19
# 295     Wolfsburg U19
# 296     U'haching U19
# 297    1.FC K'lautern
# 298     Karlsruhe U19
# 299   SC Freiburg U19
# 300     Stuttgart U17
# 301       Arsenal U18
# 302          Montréal
# 303         Vancouver
# 304       Helsingborg
# 305         Östers IF
# 306          Besiktas
# 307            Troyes
# 308       Chelsea U23
# 309        Cavalry FC
# 310          Montreal
# 311          KAA Gent
# 312         Blackburn
# 313               QPR
# 314            Austin
# 315     Liverpool U23
# 316          FC Basel
# 317         Puebla FC
# 318           Toronto
# 319   Louisville City
# 320         Vålerenga
# 321         Hatayspor
# 322         CD Izarra
# 323    Paços Ferreira
# 324            Chaves
# 325           Leixões
# 326    RSC Anderlecht
# 327       Borac Cacak
# 328          Red Star
# 329         Vojvodina
# 330     Radnicki 1923
# 331        1. FC Köln
# 332      BATE Borisov
# 333      Red Star U17
# 334      Man City U18
# 335    Apol. Limassol
# 336          Alcorcón
# 337          SD Eibar
# 338     Tottenham U21
# 339           TJ Teda
# 340     GZ Evergrande
# 341         NAC Breda
# 342        NK Domzale
# 343         FC Astana
# 344        Empoli U19
# 345       M. Tel Aviv
# 346          Jagodina
# 347            Torino
# 348   Real Sociedad B
# 349     R. Strasbourg
# 350       KV Kortrijk
# 351   OFK Beograd U19
# 352      Red Star U19
# 353     Lechia Gdansk
# 354       G. Bordeaux
# 355          VAFC U19
# 356       Aston Villa
# 357         FC Nantes
# 358  CF Rayo Majadaho
# 359      Atléti Youth
# 360          Guingamp
# 361        FC Lorient
# 362       Montpellier
# 363          Tours FC
# 364          Grenoble
# 365              Lens
# 366       AC Le Havre
# 367     Saint-Étienne
# 368            Novara
# 369      Boavista Y19
# 370          Marítimo
# 371        Olympiacos
# 372   Sacavenense U19
# 373      Sporting U19
# 374     Estoril Praia
# 375   Sporting CP U23
# 376     Internacional
# 377           SM Caen
# 378   Vitória Setúbal
# 379          Athletic
# 380         Barça U16
# 381      Cornellà U19
# 382        Valencia B
# 383    LD Alajuelense
# 384          Saprissa
# 385           Göztepe
# 386       Fredrikstad
# 387          San Jose
# 388         Konyaspor
# 389         Minnesota
# 390           Chicago
# 391         Herediano
# 392         Frosinone
# 393              León
# 394        Cincinnati
# 395           Levante
# 396          Albacete
# 397      Thonon Évian
# 398    Lausanne-Sport
# 399         Maldonado
# 400       Atlético-PR
# 401            Grêmio
# 402         São Paulo
# 403       Atlético-MG
# 404    Desportivo U20
# 405   Atlético-MG U20
# 406          EC Bahia
# 407         Santos FC
# 408        América-MG
# 409        Rio Ave FC
# 410    Fluminense U20
# 411       Shakhtar D.
# 412            Ituano
# 413       Corinthians
# 414        Fluminense
# 415    Vit. Guimarães
# 416       Avaí FC U20
# 417       Guimarães B
# 418     Dinamo Moscow
# 419         Juventude
# 420     Al-Ahli (UAE)
# 421       Coritiba FC
# 422       KV Oostende
# 423        TJ Tianhai
# 424       TJ Quanjian
# 425             AGOVV
# 426      KAA Gent U21
# 427       KSC Lokeren
# 428     Lommel United
# 429         RE Virton
# 430      Al-Duhail SC
# 431            DL Pro
# 432         DL Yifang
# 433      KRC Genk U17
# 434        Monaco U19
# 435   Suwon Bluewings
# 436          Daegu FC
# 437         FC Anyang
# 438   Jeonbuk Hyundai
# 439   Daejeon Citizen
# 440     Holstein Kiel
# 441   Albirex Niigata
# 442        SD Taishan
# 443   Pohang Steelers
# 444       Seongnam FC
# 445          BJ Guoan
# 446       Busan IPark
# 447        Gwangju FC
# 448         Al-Shabab
# 449       Vissel Kobe
# 450      Darmstadt 98
# 451      FC Bayern II
# 452      Incheon Utd.
# 453     FC Bayern U19
# 454          CQ Lifan
# 455      Omiya Ardija
# 456          Suwon FC
# 457   Daejeon Hana C.
# 458          Coventry
# 459     Liverpool U21
# 460         Hull City
# 461        Birmingham
# 462          Charlton
# 463           QPR U18
# 464     Liverpool U18
# 465         Barça U19
# 466         HN Jianye
# 467            Al-Tai
# 468         FC Dinamo
# 469      OFI Crete FC
# 470              Abha
# 471        Le Mans FC
# 472        AJ Auxerre
# 473       Servette FC
# 474    BSC Young Boys
# 475         Apejes FC
# 476     Colombe Sport
# 477          Paris FC
# 478     Recre Granada
# 479     Nkufo Academy
# 480         Granada B
# 481        SCR Altach
# 482    1.FSV Mainz 05
# 483           SH Port
# 484   Adelaide United
# 485        Basaksehir
# 486         Bursaspor
# 487           Brescia
# 488     Central Coast
# 489     Burton Albion
# 490       Ross County
# 491    Melbourne City
# 492      Hibernian FC
# 493     FC Ingolstadt
# 494     FSV Frankfurt
# 495      Al-Hilal SFC
# 496         Charlotte
# 497              SPAL
# 498       Diambars FC
# 499      Bristol City
# 500     Clermont Foot
# 501           FC Metz
# 502      Sarpsborg 08
# 503     Oslo FA Dakar
# 504          SC Braga
# 505         US Ouakam
# 506           Braga B
# 507         ASPIRE FD
# 508          Pafos FC
# 509        AC Ajaccio
# 510    CF Fuenlabrada
# 511    Rayo Vallecano
# 512           FC Thun
# 513     FC Winterthur
# 514     FC Zürich U21
# 515     M'gladbach II
# 516           FC Sion
# 517     GC Zürich U18
# 518      Grasshoppers
# 519         FC Luzern
# 520         FC Zürich
# 521         FC Lugano
# 522       FC Augsburg
# 523          FC Aarau
# 524        Granada CF
# 525     Independiente
# 526         CS Emelec
# 527            Dallas
# 528      Barcelona SC
# 529         LDU Quito
# 530          Newell's
# 531       Tigres UANL
# 532       U. de Chile
# 533          SD Aucas
# 534          Boavista
# 535          Manta FC
# 536     Santos FC U20
# 537     Uni. Católica
# 538         CD Macará
# 539       CA Talleres
# 540          Saipa FC
# 541      Esteghlal FC
# 542           Sepahan
# 543        Persepolis
# 544      NEC Nijmegen
# 545      Damash Gilan
# 546       OC Blues FC
# 547         Panionios
# 548     Al-Gharafa SC
# 549       Al-Arabi SC
# 550          Rah Ahan
# 551      Terek Grozny
# 552       Naft Tehran
# 553      Saba Battery
# 554         Östersund
# 555         Amiens SC
# 556      Syrianska FC
# 557            Rostov
# 558   Al-Ittihad Club
# 559        Ettifaq FC
# 560       Al-Ahli SFC
# 561       Al-Ahli U23
# 562           Al-Raed
# 563   Argentinos Jrs.
# 564          Belgrano
# 565      Indep'te U20
# 566      Arsenal Res.
# 567     Atl. Nacional
# 568       Estudiantes
# 569       Racing Club
# 570           Defensa
# 571       Newell's II
# 572             Ferro
# 573          Banfield
# 574          Metalist
# 575       San Lorenzo
# 576   Arsenal Sarandí
# 577      Instituto AC
# 578           Atlanta
# 579   Rosario Central
# 580     Górnik Zabrze
# 581   Rozwój Katowice
# 582         Krasnodar
# 583       Lech Poznan
# 584     Akhmat Grozny
# 585       Wisla Plock
# 586       Jagiellonia
# 587       Loko Moscow
# 588   Arka Gdynia U19
# 589      Bordeaux U19
# 590        MSK Zilina
# 591        Podbrezova
# 592    Anderlecht U21
# 593         GKS Tychy
# 594    Anderlecht U17
# 595         Benevento
# 596     Piast Gliwice
# 597          Ruch U19
# 598         West Brom
# 599         Sivasspor
# 600    Pogon Szczecin
# 601     PAOK Salonika
# 602             Derby
# 603          Lech U19
# 604          Cracovia
# 605    Zaglebie Lubin
# 606    L. Dzierzoniow
# 607          Lubin II
# 608       Udinese U19
# 609    Znicz Pruszkow
# 610          Legia II
# 611        Legia Yth.
# 612    Greuther Fürth
# 613         SC Bastia
# 614        Djurgården
# 615      Steadfast FC
# 616          Hammarby
# 617     Leicester U21
# 618     FC St. Gallen
# 619        AS Trencin
# 620       Accra Lions
# 621       JS Kairouan
# 622         Esperance
# 623        CS Sfaxien
# 624     Club Africain
# 625          ES Sahel
# 626      FC Voluntari
# 627       Ferencváros
# 628       Salernitana
# 629     Chamois Niort
# 630           ESS U19
# 631      Monaco Youth
# 632       Man Utd U18
# 633        ACBB Youth
# 634         Rosenborg
# 635       Al-Wehda FC
# 636          Elfsborg
# 637       Red Star FC
# 638      El Mokawloon
# 639           Zamalek
# 640    Stade Gabèsien
# 641         Al-Ain FC
# 642    Stade Tunisien

# %%
list(s2.difference(s1))
# Out:
# ['AFC Wimbledon',
#  'Asante Kotoko',
#  'Alanyaspor',
#  'Bilbao Athletic',
#  'Los Angeles',
#  'Salt Lake',
#  'FC Juárez',
#  'Columbus',
#  'Portsmouth',
#  'Kayserispor',
#  'Gimcheon Sangmu',
#  'MK Dons',
#  'Luton',
#  'Houston',
#  'Cremonese',
#  'CD Lugo',
#  'Millonarios',
#  'Fagiano Okayama',
#  'Hearts of Oak',
#  'Coton Sport FC',
#  'Colorado 2',
#  'KMSK Deinze',
#  'KAS Eupen',
#  'Puntarenas FC',
#  'Guanacasteca',
#  'Deportivo Guadalajara',
#  'St. Mirren',
#  'Atromitos Athen',
#  'Al-Wakrah SC',
#  'Al-Ahli SC',
#  'Heart of Midl.',
#  'Shabab Dubai',
#  'Miami',
#  'Grecia',
#  'Sydney FC',
#  'Shonan Bellmare',
#  'Cádiz CF',
#  'KV Mechelen',
#  'St. Johnstone',
#  'Ponferradina',
#  'Swindon Town',
#  'US Monastir',
#  'FC Seoul',
#  'Imbabura SC',
#  'Club Nacional',
#  'Nagoya Grampus',
#  'Aris Saloniki',
#  'SH Shenhua',
#  'Omonia Nikosia',
#  'Vejle BK',
#  'Panetolikos',
#  'Al-Fateh',
#  'AD San Carlos',
#  'Kuwait SC']

# %%
colors_d = df_cntr[df_cntr.country.isin(set(pd.read_csv('team_league.csv').current_league_country))].set_index('country').to_dict()['hex']
colors_d.update({'United States' : '#3C3B6E', 'Wales' : '#CF1E26', 'England' : '#FFFFFF'})

df_club['country'] = df_club.Id.map(clubs_countries)
df_club['color'] = df_club.country.map(colors_d)
df_club['color'] = df_club['color'].fillna('#808080')
df_club.set_index('Id').to_csv('club_colors.csv')
print(len(df_club.dropna()))
df_club
# Out:
# 239
#                  Id      country    color
# 0           Man Utd      England  #FFFFFF
# 1              Ajax  Netherlands  #21468B
# 2     Werder Bremen      Germany  #000000
# 3           Everton      England  #FFFFFF
# 4     PSV Eindhoven  Netherlands  #21468B
# ..              ...          ...      ...
# 638    El Mokawloon          NaN  #808080
# 639         Zamalek        Egypt  #000000
# 640  Stade Gabèsien          NaN  #808080
# 641       Al-Ain FC          NaN  #808080
# 642  Stade Tunisien          NaN  #808080
#
# [643 rows x 3 columns]

# %%
df_node_feat = pd.read_csv('club_migration_networks_v4_node_attributes.csv')
top50 = list(df_node_feat.sort_values(by = 'Weighted Degree', ascending = False).head(25).Label)

def get_new_label(x, top50):
    if x in top50:
        return x
    else:
        return ''
    

df_node_feat['newlabel'] = df_node_feat.Label.apply(lambda x: get_new_label(x, top50))
df_node_feat.set_index('Id', inplace = True)
df_node_feat[['newlabel']].to_csv('node_clubs_label.csv')

# %%
from collections import Counter
Counter(pd.read_csv('club_colors.csv').color).most_common(3)
# Out:
# [('#808080', 409), ('#FFFFFF', 37), ('#000000', 23)]

# %%
len(pd.read_csv('club_colors.csv'))
# Out:
# 643

# %%
CIKK CLUB NETWORK SZÁMOK ÁTJAVÍTANI
